# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer

# %%
df = pd.read_csv('C:\\Users\\Administrator\\Downloads\\complete-data.csv')

# %%
df.head()
# Out:
#    frame_number gender emotion  year    movie_name
# 0            28  woman   happy  2014  dedh_ishqiya
# 1            62  woman   happy  2014  dedh_ishqiya
# 2            60    man   angry  2014  dedh_ishqiya
# 3            60    man     sad  2014  dedh_ishqiya
# 4            60    man   angry  2014  dedh_ishqiya

# %%
df.tail()
# Out:
#        frame_number  gender   emotion  year   movie_name
# 32192            18       1     happy  2016  housefull_3
# 32193            25       1   neutral  2016  housefull_3
# 32194            25       1   neutral  2016  housefull_3
# 32195            25       1     happy  2016  housefull_3
# 32196            31       1  surprise  2016  housefull_3

# %%
df.size
# Out:
# 160985

# %%
df.corr()
# Out:
#               frame_number    gender      year
# frame_number      1.000000 -0.019945 -0.103745
# gender           -0.019945  1.000000 -0.016610
# year             -0.103745 -0.016610  1.000000

# %%
df.columns
# Out:
# Index(['frame_number', 'gender', 'emotion', 'year', 'movie_name'], dtype='object')

# %%
df.dtypes
# Out:
# frame_number     int64
# gender          object
# emotion         object
# year             int64
# movie_name      object
# dtype: object

# %%
df.isnull().isnull().sum()
# Out:
# frame_number    0
# gender          0
# emotion         0
# year            0
# movie_name      0
# dtype: int64

# %%
df.describe()
# Out:
#        frame_number        gender          year
# count  32197.000000  32197.000000  32197.000000
# mean      89.766189      0.684598   2013.555052
# std       82.595545      0.464683      2.545130
# min        0.000000      0.000000   2008.000000
# 25%       45.000000      0.000000   2012.000000
# 50%       77.000000      1.000000   2014.000000
# 75%      115.000000      1.000000   2016.000000
# max      942.000000      1.000000   2017.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32197 entries, 0 to 32196
# Data columns (total 5 columns):
# frame_number    32197 non-null int64
# gender          32197 non-null int64
# emotion         32197 non-null object
# year            32197 non-null int64
# movie_name      32197 non-null object
# dtypes: int64(3), object(2)
# memory usage: 1.2+ MB

# %%
df[df.gender == 'woman'].size
# Out:
# 50775

# %%
df[df.gender == 'man'].size
# Out:
# 110210

# %%
df_names = df

# %%
df_names.gender.replace({'woman':0,'man':1},inplace=True)

# %%
df_names.gender.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
Xfeatures =df_names['movie_name']

# %%
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()
# Out:
# ['102_not_out',
#  '1920',
#  '1920_london',
#  '2_states',
#  '31st_october',
#  '332_mumbai_to_india',
#  '3_a',
#  '3_idiots',
#  '3g',
#  '404',
#  '7_hours_to_go',
#  '7_khoon_maaf',
#  '8_x_10_tasveer',
#  '99',
#  '_40',
#  '_a_billion_dreams',
#  '_a_prayer_for_rain',
#  '_a_question_mark',
#  '_aur_main',
#  '_birth_of_a_nation',
#  '_biwi_aur_gangster_returns',
#  '_co',
#  '_courage_has_no_limit',
#  '_da',
#  '_damdaar',
#  '_dead_or_alive',
#  '_ek_prem_katha',
#  '_fun_begins',
#  '_ka',
#  '_king_of_kings',
#  '_lucky_oye',
#  '_me',
#  '_movie',
#  '_msg_lion_heart_2',
#  '_rise_of_banda_singh_bahadur',
#  '_salesman_of_the_year',
#  '_see_your_evil',
#  '_silences_have_secrets',
#  '_sons',
#  '_the_chase_continues',
#  '_the_conclusion',
#  '_the_desert_mermaid',
#  '_the_epic',
#  '_the_flim',
#  '_the_mall',
#  '_the_messenger',
#  '_the_story_of_pokhran',
#  '_the_war_within',
#  '_the_warrior_lion_heart',
#  '_the_warrior_prince',
#  'a_death_in_the_gunj',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X
y = df_names.gender

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.689064558629776

# %%
df["gender"].value_counts().plot.pie()

# %%
df["gender"].value_counts().plot.bar()

# %%
df["year"].plot(kind='hist')

# %%
print("Accuracy of Model",clf.score(X_test,y_test)*100,"%")
# Out:
# Accuracy of Model 68.9064558629776 %

# %%
print("Accuracy of Model",clf.score(X_train,y_train)*100,"%")
# Out:
# Accuracy of Model 70.77094246905567 %
